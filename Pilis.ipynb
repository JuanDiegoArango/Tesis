# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dt=0.01
tiempo=int(100.0/dt)
Linst=zeros(tiempo)
fuerzas=zeros(tiempo+1)
Kb=1.38*10**-5
T=300.0

# %% [markdown]
# monomeros.

# %%
Ntot=1e3
Na=Ntot
Nb=0

# %% [markdown]
# Longitudes

# %%
La0=1.0
Lb0=2.0
La=La0
lp=3.3

# %% [markdown]
# Funciones

# %%
def fuerza2(x,c):
    return b/4*((1-((x))/c)**-2-1+4*(x)/c)

def probabilidad_de_transicion(delta_V,f,delta_X):
    return v*exp(-(delta_V-delta_X*f))*dt

def nuevo_La(f,Numero):
    return (f/ka)+La0*Numero

def fuerza1(x,a):
    return ka*(x-a)

# %%
ka=660.0
v=float(6e9)
delta_V_AB=21.7
delta_X_AB=0.7
L_inicial=La0*Ntot




monomeros=ones(Ntot)
cambio_L=0.00001
posiciones_libres=0
coeficiente_polinomio=zeros(4)
for j in range (0,tiempo):

    L=L_inicial+cambio_L*j*dt
    pa=random.uniform()
    p=probabilidad_de_transicion(delta_V_AB,fuerzas[j],delta_X_AB)
    
    if (pa<p) & ((Na)>0.0):
        monomeros[posiciones_libres]=2   
        posiciones_libres=posiciones_libres+1
        
    Na=len(monomeros[monomeros==1])    
    Nb=len(monomeros[monomeros==2]) 
    
    if(Nb==0)&(Na==Ntot):
        
        fuerzas[j+1]=fuerza1(L,L_inicial)

    elif(Nb>0)&(Na<Ntot):
   
        a=La0*Na
        b=Kb*T/4
        c=Lb0*Nb
        
        coeficiente_polinomio[0]=4*(b+c*ka)
        coeficiente_polinomio[1]=-(c)*(8*c*ka+4*ka*(L-a)+9*b)
        coeficiente_polinomio[2]=(2*c**2)*(2*c*ka+4*ka*(L-a)+3*b)
        coeficiente_polinomio[3]=4*(c**3)*(ka)*(a-L)

        LB=roots(coeficiente_polinomio)
        Lb=absolute(min(LB[(LB==LB.conjugate()) & (LB>0)]))
        fuerzas[j+1]=fuerza2(Lb,c)
        print fuerzas[j]
        
        La=nuevo_La(fuerza2(Lb,c),Na)

    Linst[j]=L
# Out:
# 0.00118799996699
# 0.00129374984416
# 0.00129375010291
# 0.00129375036166
# 0.00129375062041
# 0.00129375087916
# 0.00129375113791
# 0.00129375139666
# 0.00129375165541
# 0.00129375191416
# 0.00129375217291
# 0.00129375243166
# 0.0012937526904
# 0.00129375294915
# 0.0012937532079
# 0.00129375346665
# 0.0012937537254
# 0.00129375398415
# 0.0012937542429
# 0.00129375450165
# 0.0012937547604
# 0.00129375501915
# 0.0012937552779
# 0.00129375553665
# 0.0012937557954
# 0.00129375605416
# 0.00129375631291
# 0.00129375657166
# 0.00129375683041
# 0.00129375708916
# 0.00129375734791
# 0.00129375760666
# 0.00129375786541
# 0.00129375812416
# 0.00129375838291
# 0.00129375864166
# 0.00129375890041
# 0.00129375915917
# 0.00129375941792
# 0.00129375967667
# 0.00129375993542
# 0.00129376019417
# 0.00129376045292
# 0.00129376071167
# 0.00129376097042
# 0.00129376122918
# 0.00129376148793
# 0.00129376174668
# 0.00129376200543
# 0.00129376226418
# 0.00129376252294
# 0.00129376278169
# 0.00129376304044
# ...

# %%
r=linspace(0,len(fuerzas),len(fuerzas))
scatter(r,fuerzas)
plot(r,fuerzas)
ylim(0,0.002)
# Out:
# (0, 0.002)

# %%
plot(monomeros)
